# %% [markdown]
# <a href="https://colab.research.google.com/github/bhjin97/DL_rep/blob/main/1_%EC%8B%A0%EA%B2%BD%EB%A7%9D%EC%9D%98_%EA%B5%AC%EC%A1%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.19.0'

# %%
# iris dateset
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
from sklearn.neural_network import MLPClassifier
# 사이킷런(sklearn)에서 다층 퍼셉트론(MLP, Multi-Layer Perceptron) 분류기 클래스 불러오기
# 인공신경망 기반으로 분류 문제를 해결하는 모델임

mlp = MLPClassifier(
    hidden_layer_sizes=(50, 30),  # 은닉층 구조: 첫 번째 은닉층 50개 뉴런, 두 번째 은닉층 30개 뉴런
    activation='logistic',        # 각 뉴런의 활성화 함수: logistic(=시그모이드 함수)
    solver='adam',                # 최적화 알고리즘(가중치 학습 방법): Adam Optimizer
    max_iter=1000                 # 학습 반복 횟수(epochs 개념과 유사) → 최대 1000번 반복
)
# 위 설정으로 MLPClassifier 객체 생성

mlp.fit(X_train, y_train)
# 훈련 데이터(X_train, y_train)를 사용해 신경망 학습 수행
# 가중치와 편향을 조정하여 입력 → 은닉층 → 출력층 구조에 맞게 모델을 최적화함

mlp.score(X_test, y_test)
# 학습된 모델을 테스트 데이터(X_test, y_test)에 적용해 정확도(accuracy) 계산
# 반환값: 0~1 사이의 실수 (예: 0.92 → 92% 정확도)
# Out:
# 1.0

# %%
import sklearn
# 사이킷런 라이브러리 불러오기

a = sklearn.neural_network.MLPClassifier(
    hidden_layer_sizes=(100,),     # 은닉층 뉴런 개수 설정 → (100,)이면 은닉층 1개, 뉴런 100개
    activation='relu',             # 활성화 함수: 'relu' (비선형성 부여, 깊은 신경망에서 성능 좋음)
    solver='adam',                 # 최적화 알고리즘: Adam Optimizer (확률적 경사하강법 변형, 빠르고 안정적)
    alpha=0.0001,                  # L2 규제(가중치 패널티) 강도 → 과적합 방지용 하이퍼파라미터
    batch_size='auto',             # 미니배치 크기 ('auto'면 min(200, 샘플 수)로 자동 설정)
    learning_rate='constant',      # 학습률 스케줄: 'constant'는 고정 학습률 사용
    learning_rate_init=0.001,      # 초기 학습률 값 → Adam일 때 기본적으로 0.001
    power_t=0.5,                   # 학습률이 'invscaling'일 때 적용되는 감쇠 지수 (여기선 사용 X)
    max_iter=200,                  # 최대 학습 반복 횟수 (에포크 수 개념)
    shuffle=True,                  # 각 epoch마다 훈련 데이터를 섞을지 여부 (일반적으로 True)
    random_state=None,             # 난수 시드 고정 (재현성 위해 int 값 줄 수 있음)
    tol=0.0001,                    # 수렴 기준 → loss 개선 폭이 tol보다 작으면 학습 조기 종료
    verbose=False,                 # 학습 과정 중 로그 출력 여부 (True로 하면 epoch마다 loss 출력)
    momentum=0.9,                  # 모멘텀(이전 기울기 반영 정도, SGD 기반 solver에서만 적용)
    nesterovs_momentum=True,       # 네스테로프 모멘텀 사용 여부 (SGD일 때 효과 있음, Adam에서는 무시)
    early_stopping=False,          # 조기 종료 여부 (True면 validation set에서 성능 향상 없으면 학습 중단)
    validation_fraction=0.1,       # 검증 세트 비율 (early_stopping=True일 때만 사용, 10% 기본)
    beta_1=0.9,                    # Adam의 1차 모멘트 추정 계수 (평균 기울기 감쇠율)
    beta_2=0.999,                  # Adam의 2차 모멘트 추정 계수 (평균 제곱 기울기 감쇠율)
    epsilon=1e-08,                 # Adam에서 분모 0 방지용 작은 상수
    n_iter_no_change=10            # tol 기준 만족 못하면 연속 몇 번 더 반복할지 (조기 종료 관련)
)

# %%
a.fit(X_train, y_train)
a.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.9555555555555556

# %%
# 텐서플로우 신경망 구성

# %%
import tensorflow.compat.v1 as tf
# TensorFlow 1.x API를 불러오기 위해 compat.v1 모듈을 tf라는 이름으로 임포트
# TensorFlow 2.x에서는 기본적으로 tf.placeholder, tf.Session 같은 1.x 기능이 제거되어 있기 때문에
# compat.v1을 통해서만 옛날 스타일 코드를 사용할 수 있음

tf.disable_v2_behavior()
# TensorFlow 2.x의 즉시 실행(Eager Execution)과 v2 기본 동작을 끄고
# TensorFlow 1.x 실행 방식(graph execution, session 기반)으로 동작하도록 설정
# 즉, tf.placeholder, tf.Session 등을 그대로 사용할 수 있게 만들어 줌
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X = tf.placeholder(tf.float32, [None, 4])
# 입력 데이터 X를 담을 placeholder(자리표시자) 정의
# dtype: float32 → 입력 값 자료형은 32비트 실수
# shape: [None, 4] → 행은 미정(None: 배치 크기 가변), 열은 4개 (즉, 특성이 4개인 벡터)

y = tf.placeholder(tf.float32, [None, 3])
# 정답 라벨 y를 담을 placeholder 정의
# dtype: float32 → 레이블 자료형은 32비트 실수 (보통 원-핫 인코딩된 벡터로 사용)
# shape: [None, 3] → 행은 미정(샘플 수에 따라 달라짐), 열은 3개 (즉, 클래스가 3개인 분류 문제)

# %%
## W 가중치 , b 편향 - 1 layer

# %%
# W1: 첫 번째 가중치 행렬을 정의합니다. 
# tf.Variable은 텐서플로우가 학습 과정에서 값을 변경할 수 있도록 하는 '변수'입니다.
# tf.random_normal([4, 50])은 평균이 0이고 표준편차가 1인 정규분포에서 추출된
# 무작위 값으로 이루어진 [4, 50] 형태의 텐서를 생성합니다.
# 여기서 4는 입력 특성(feature)의 개수이며, 50은 첫 번째 은닉 계층의 뉴런(노드) 개수를 의미합니다.
# 
W1 = tf.Variable(tf.random_normal([4, 50]))

# b1: 첫 번째 바이어스 벡터를 정의합니다.
# tf.Variable은 위와 동일한 역할을 합니다.
# tf.zeros([50])는 모든 값이 0으로 채워진 [50] 형태의 텐서를 생성합니다.
# 바이어스는 각 뉴런에 더해지는 상수값으로, 모델의 표현력을 높이는 역할을 합니다.
# 이 텐서의 크기(50)는 W1의 두 번째 차원과 동일하게 설정되어야 합니다.
b1 = tf.Variable(tf.zeros([50]))

# h1: 첫 번째 은닉 계층의 출력을 계산합니다.
# tf.matmul(X, W1)은 입력 데이터 텐서(X)와 가중치 행렬(W1)의 행렬 곱셈을 수행합니다.
# 이 연산은 각 입력 특성과 가중치를 곱하고 합산하여 뉴런의 '가중합'을 계산합니다.
# +b1은 계산된 가중합에 바이어스(b1)를 더하는 연산입니다.
# tf.nn.sigmoid(...)는 행렬 곱셈과 바이어스가 더해진 결과에 시그모이드(sigmoid) 활성화 함수를 적용합니다.
# 시그모이드 함수는 뉴런의 출력을 0과 1 사이의 값으로 변환하며, 비선형성을 도입하여 모델이 복잡한 패턴을 학습할 수 있게 돕습니다.
# 

[Image of a sigmoid function graph]

h1 = tf.nn.sigmoid(tf.matmul(X, W1) + b1)

# %%
## 2 layer - 30 node로 구성

# %%
# 바로 앞 레이어의 노드 수가 50개 이므로 50개를 받음 / 30개 출력
W2 = tf.Variable(tf.random_normal([50,30]))
b2 = tf.Variable(tf.zeros([30]))
h2 = tf.nn.sigmoid(tf.matmul(h1, W2)+b2)

# %%
W3 = tf.Variable(tf.random_normal([30,3]))
b3 = tf.Variable(tf.zeros([3]))
h3 = tf.nn.softmax(tf.matmul(h2, W3)+ b3)

# %%
cross_entropy = -tf.reduce_sum(y * tf.log(h3), reduction_indices=[1])
# 교차 엔트로피 손실(cross-entropy loss)을 직접 계산
# y  : 실제 레이블 (원-핫 인코딩된 벡터, shape = [배치, 클래스])
# h3 : 모델의 출력 (softmax 결과, 예측 확률 분포, shape = [배치, 클래스])
# y * log(h3) : 정답 클래스 위치에 해당하는 확률의 로그값만 남음
# reduce_sum(..., reduction_indices=[1]) : 클래스 축(=열, axis=1)을 따라 합산
# 따라서 각 샘플별 손실 값을 얻음

loss = tf.reduce_mean(cross_entropy)
# 배치 내 모든 샘플의 손실 평균을 구함
# 즉, 학습 중 최적화할 최종 손실 스칼라 값

train = tf.train.AdamOptimizer().minimize(loss)
# Adam Optimizer(Adaptive Moment Estimation)로 최적화 알고리즘 정의
# loss를 최소화하도록 네트워크 가중치와 편향을 자동 업데이트
# train은 "학습을 한 스텝 수행하는 연산(operation)"이 됨

# %%
import pandas as pd
# 판다스 라이브러리 불러오기 (라벨 원-핫 인코딩에 사용)

feed_train = {X: X_train, y: pd.get_dummies(y_train).values}
# 학습 데이터를 딕셔너리 형태로 준비
# X : 입력 placeholder → 훈련 데이터 (X_train)
# y : 출력 placeholder → 훈련 라벨 (y_train을 원-핫 인코딩하여 사용)
# pd.get_dummies(y_train).values : 정수 라벨을 원-핫 인코딩 벡터로 변환

init = tf.global_variables_initializer()
# 모든 변수(가중치, 편향)를 초기화하는 연산 정의
# 초기값은 보통 무작위로 설정됨

sess = tf.Session()
# TensorFlow 1.x 실행을 위한 세션(Session) 생성
# 그래프에 정의된 연산을 실제로 실행할 수 있게 됨

sess.run(init)
# 앞서 정의한 변수 초기화 연산 실행
# 신경망 학습을 시작하기 전 반드시 해줘야 함

for i in range(1000):
    # 학습 반복 루프 (1000번 학습)

    sess.run(train, feed_dict=feed_train)
    # 한 번의 학습 스텝 실행
    # train은 옵티마이저(minimize(loss))로 정의된 학습 연산
    # feed_dict로 실제 데이터를 placeholder(X, y)에 주입

    if i % 100 == 0:
        # 100번마다 손실(loss)을 출력해 학습 상황 모니터링

        tr_loss = sess.run(loss, feed_dict=feed_train)
        # 현재 학습 데이터에 대한 손실 함수 값 계산

        print("Step %d, %.5f" % (i, tr_loss))
        # 현재 학습 단계(i)와 손실 값 출력
# Out:
# Step 0, 6.80124
# Step 100, 0.68918
# Step 200, 0.30541
# Step 300, 0.15972
# Step 400, 0.11912
# Step 500, 0.09210
# Step 600, 0.08000
# Step 700, 0.07277
# Step 800, 0.06764
# Step 900, 0.06371

# %%
correct_prediction = tf.equal(tf.argmax(h3, 1), tf.argmax(y, 1))
# 예측 결과와 실제 정답을 비교해 일치 여부(True/False)를 판별
# h3 : 모델 출력 (softmax 확률 벡터, shape=[배치, 클래스])
# tf.argmax(h3, 1) : 각 샘플마다 가장 확률이 높은 클래스(예측 라벨) 인덱스
# tf.argmax(y, 1)  : 실제 라벨의 원-핫 벡터에서 1의 위치(정답 클래스) 인덱스
# tf.equal(...)    : 두 값이 같으면 True, 다르면 False (예: [True, False, True, ...])

accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
# True/False를 float32(1.0/0.0)로 변환
# reduce_mean : 전체 배치에서 평균값 계산 → 정확도(accuracy)가 됨
# 예: [True, False, True] → [1.0, 0.0, 1.0] → 평균=0.666...

feed_test = {X: X_test, y: pd.get_dummies(y_test).values}
# 테스트 데이터 입력 준비
# X_test : 입력 데이터
# y_test : 정수 라벨을 원-핫 인코딩하여 placeholder y에 맞춤

print(sess.run(accuracy, feed_dict=feed_test))
# 세션에서 accuracy 연산 실행
# feed_dict로 테스트 데이터를 넣어 정확도 계산
# 출력: 0.85 → 85% 정확도 같은 실수 값
# Out:
# 1.0

# %%
sess.close()

# %%
from tensorflow.keras.models import Sequential
model = Sequential()
model
# Out:
# <Sequential name=sequential, built=False>

# %%
from tensorflow.keras.layers import Input, Dense
# model = Sequential()
# Sequential()은 Keras에서 가장 기본적인 모델 구성 방식입니다.
# 층(layer)들을 순차적으로 쌓아 올리는 구조를 가집니다.
# 마치 레고 블록을 하나씩 쌓아 올리는 것처럼,
# 각 층의 출력이 다음 층의 입력으로 전달됩니다.
model = Sequential()

# model.add(Input(shape=(4,)))
# Input(shape=(4,))는 모델의 첫 번째 층으로, 입력 데이터의 형태를 정의합니다.
# shape=(4,)는 각 입력 데이터가 4개의 특성(feature)을 가지고 있음을 의미합니다.
# 예를 들어, 한 명의 고객을 4가지 정보(나이, 소득 등)로 표현할 때 사용될 수 있습니다.
model.add(Input(shape=(4,)))

# model.add(Dense(50, activation='sigmoid'))
# Dense는 '완전 연결(Fully Connected)' 층을 의미합니다.
# 이 층의 모든 뉴런이 이전 층의 모든 뉴런과 연결되어 있습니다.
# 50은 이 층에 있는 뉴런(노드)의 개수입니다.
# activation='sigmoid'는 각 뉴런의 출력에 시그모이드 활성화 함수를 적용합니다.
# 시그모이드 함수는 출력을 0과 1 사이의 값으로 압축하여 모델에 비선형성을 부여합니다.
# 이는 모델이 복잡한 패턴을 학습할 수 있게 돕습니다.
# 

[Image of a sigmoid function graph]

model.add(Dense(50, activation='sigmoid'))

# model.add(Dense(30, activation='sigmoid'))
# 이 층은 두 번째 은닉 층입니다.
# 이전 층(뉴런 50개)과 완전 연결되어 있으며, 이 층에는 30개의 뉴런이 있습니다.
# 마찬가지로 시그모이드 활성화 함수를 사용합니다.
model.add(Dense(30, activation='sigmoid'))

# model.add(Dense(3, activation='softmax'))
# 이 층은 모델의 '출력 층'입니다.
# 3은 최종 출력의 차원 수, 즉 분류해야 할 클래스의 개수입니다.
# 예를 들어, 사과, 바나나, 오렌지 3가지 중 하나를 분류하는 문제라면
# 출력 층의 뉴런 개수는 3이 됩니다.
# activation='softmax'는 다중 클래스 분류 문제에 주로 사용되는 활성화 함수입니다.
# 이 함수는 모든 출력 뉴런의 값을 0과 1 사이의 확률 값으로 변환하며,
# 이 확률들의 총합이 1이 되도록 정규화합니다.
# 이를 통해 각 클래스에 속할 확률을 직관적으로 해석할 수 있습니다.
# 
model.add(Dense(3, activation='softmax'))

# %%
# model.compile(...)
# compile 메서드는 모델의 학습을 위한 설정을 마치는 단계입니다.
# 이 설정을 바탕으로 모델은 데이터를 통해 학습을 시작할 준비가 됩니다.
model.compile(

    # optimizer='adam'
    # '옵티마이저(Optimizer)'는 모델의 가중치(weights)를 어떻게 업데이트할지 결정하는 알고리즘입니다.
    # adam은 'Adaptive Moment Estimation'의 약자로, 가장 널리 사용되는 효율적인 옵티마이저 중 하나입니다.
    # 
    # 이 옵티마이저는 각 매개변수(parameter)에 대해 학습률(learning rate)을 동적으로 조절하여
    # 빠르고 안정적으로 최적의 가중치를 찾도록 도와줍니다.
    optimizer='adam',

    # loss = 'sparse_categorical_crossentropy'
    # '손실 함수(Loss Function)'는 모델의 예측 결과가 정답과 얼마나 다른지를 수치화하는 함수입니다.
    # 이 값이 작을수록 모델의 예측이 정확하다는 의미입니다.
    # 'sparse_categorical_crossentropy'는 다중 클래스 분류 문제에 사용되는 손실 함수입니다.
    # 특히, 정답 라벨이 원-핫 인코딩(one-hot encoding) 형태가 아닌,
    # 0, 1, 2와 같은 정수(sparse) 형태로 주어졌을 때 사용됩니다.
    # 
    loss = 'sparse_categorical_crossentropy',

    # metrics = ['accuracy']
    # '평가 지표(Metric)'는 모델의 성능을 측정하는 기준입니다.
    # 손실 함수와 달리, 이 지표는 학습 과정에서 모델의 성능을 사람이 이해하기 쉬운 형태로 보여주기 위해 사용됩니다.
    # 'accuracy'는 가장 흔한 지표로, 전체 예측 중 정답을 맞힌 비율을 의미합니다.
    metrics = ['accuracy']
)

# %%
model.fit(X_train, y_train, epochs=300, verbose = 1)
# Out:
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3205 - loss: 1.2892
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3278 - loss: 1.1996
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3778 - loss: 1.1097
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3611 - loss: 1.0956
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3090 - loss: 1.0984
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4044 - loss: 1.0757
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7041 - loss: 1.0712
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6837 - loss: 1.0695
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5813 - loss: 1.0636
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5012 - loss: 1.0678
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6077 - loss: 1.0540
# Epoch 12/300
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0590
# [0.05693947523832321, 1.0]

# %%
import torch
torch.__version__
# Out:
# '2.8.0+cu126'

# %%
# if torch.cuda.is_available():
# PyTorch의 torch.cuda.is_available() 함수는 현재 시스템에 NVIDIA GPU가 설치되어 있고,
# CUDA(Compute Unified Device Architecture)가 올바르게 설정되어 있는지 확인합니다.
# 이 함수는 GPU를 사용할 수 있으면 True를, 그렇지 않으면 False를 반환합니다.
# GPU를 사용할 수 없는 환경에서 GPU 관련 코드를 실행하면 에러가 발생할 수 있으므로,
# 이 조건문을 통해 안전하게 코드를 실행할 수 있습니다.
if torch.cuda.is_available():
  
  # torch.cuda.get_device_name(0)
  # 만약 GPU를 사용할 수 있다면, 이 함수는 첫 번째 GPU(장치 인덱스 0)의 이름을 반환합니다.
  # 예를 들어, 'GeForce RTX 3080'과 같은 문자열을 출력할 수 있습니다.
  # GPU가 여러 개인 경우, get_device_name(1), get_device_name(2) 등으로
  # 각 GPU의 이름을 확인할 수 있습니다.
  torch.cuda.get_device_name(0)

# %%
# iris dateset
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data
y = iris.target
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
# import torch.nn as nn
# torch.nn은 PyTorch에서 신경망을 구축하는 데 필요한 모든 모듈과 클래스를 담고 있는 패키지입니다.
# nn.Linear, nn.Sigmoid, nn.Softmax 등이 모두 이 패키지 안에 포함되어 있습니다.
import torch.nn as nn

# model = nn.Sequential(...)
# nn.Sequential은 순차적인 방식으로 계층들을 연결하여 신경망을 구축하는 컨테이너입니다.
# 내부에 정의된 계층들이 순서대로 실행됩니다.
model = nn.Sequential(

    # nn.Linear(4, 50), nn.Sigmoid()
    # 첫 번째 계층: 입력 층과 첫 번째 은닉 층을 정의합니다.
    # nn.Linear(in_features, out_features)는 완전 연결(Fully Connected) 계층을 생성합니다.
    # 4는 입력 특성(feature)의 개수, 50은 첫 번째 은닉 계층의 뉴런 개수입니다.
    # nn.Sigmoid()는 이 선형 계층의 출력에 시그모이드 활성화 함수를 적용합니다.
    # 
    nn.Linear(4, 50), nn.Sigmoid(),

    # nn.Linear(50, 30), nn.Sigmoid()
    # 두 번째 은닉 계층: 이전 계층(50개 뉴런)의 출력을 입력으로 받고, 30개의 뉴런을 가진 계층을 생성합니다.
    # 마찬가지로 시그모이드 활성화 함수를 사용합니다.
    nn.Linear(50, 30), nn.Sigmoid(),

    # nn.Linear(30, 3), nn.Softmax(dim=1)
    # 출력 계층: 이전 계층(30개 뉴런)의 출력을 입력으로 받고, 3개의 뉴런을 가진 출력 계층을 생성합니다.
    # 3은 분류해야 할 클래스의 개수입니다.
    # nn.Softmax(dim=1)은 다중 클래스 분류 문제에서 사용되는 활성화 함수입니다.
    # dim=1은 행(row)을 기준으로 소프트맥스 함수를 적용하여, 각 샘플의 모든 출력값을 합쳤을 때 1이 되도록 합니다.
    # 이로써 각 뉴런의 출력이 해당 클래스에 속할 확률을 나타내게 됩니다.
    nn.Linear(30, 3), nn.Softmax(dim=1)
)

# %%
# import torch.optim as optim
# torch.optim은 PyTorch에서 다양한 최적화 알고리즘을 제공하는 패키지입니다.
# Adam, SGD(Stochastic Gradient Descent) 등 모델을 훈련시키는 데 사용되는 알고리즘을 포함하고 있습니다.
import torch.optim as optim

# # w의 초기값 설정
# for layer in model:
#   if isinstance(layer, nn.Linear):
#     nn.init.xavier_uniform_(layer.weight)
# 이 코드는 모델의 가중치(w)를 특정 방식으로 초기화합니다.
# for layer in model: 모델 내의 모든 계층을 순회합니다.
# if isinstance(layer, nn.Linear): 현재 계층이 완전 연결(nn.Linear) 계층인지 확인합니다.
# nn.init.xavier_uniform_(layer.weight): 'Xavier 초기화' 기법을 사용하여 가중치를 초기화합니다.
# 이 기법은 가중치를 특정 분포(여기서는 균등 분포)에서 무작위로 추출하여,
# 학습 초기에 신호가 너무 커지거나 작아지는 것을 방지합니다.
# 이는 모델의 학습을 더 안정적으로 만들어 줍니다.
# 
for layer in model:
  if isinstance(layer, nn.Linear):
    nn.init.xavier_uniform_(layer.weight)

# # 손실함수 정의
# crit = nn.CrossEntropyLoss()
# 손실 함수(Loss Function)는 모델의 예측값과 실제 정답 사이의 오차를 계산하는 함수입니다.
# nn.CrossEntropyLoss()는 다중 클래스 분류 문제에 가장 널리 사용되는 손실 함수입니다.
# 이 함수는 내부적으로 소프트맥스(Softmax)와 로그(Log)를 결합하여 안정적인 계산을 제공하며,
# 정답 라벨이 정수(sparse) 형태로 주어질 때 사용하기 적합합니다.
crit = nn.CrossEntropyLoss()

# # optimizer
# opt = optim.Adam(model.parameters())
# 옵티마이저(Optimizer)는 손실 함수가 계산한 오차를 바탕으로 모델의 가중치를 업데이트하는 역할을 합니다.
# optim.Adam(...)은 가장 널리 사용되는 효율적인 최적화 알고리즘인 'Adam'을 사용하도록 설정합니다.
# model.parameters()는 모델 내의 모든 학습 가능한 매개변수(가중치와 바이어스)를 옵티마이저에 전달합니다.
# 옵티마이저는 이 매개변수들을 손실을 최소화하는 방향으로 조정해 나갑니다.
opt = optim.Adam(model.parameters())

# %%
# for epoch in range(300):
# '에포크(epoch)'는 전체 훈련 데이터를 한 번 모두 통과시키는 과정을 의미합니다.
# 이 코드는 모델을 총 300번의 에포크 동안 학습시키겠다는 뜻입니다.
# 학습 과정에서 에포크 횟수를 늘리면 모델이 데이터를 더 많이 학습하여 성능이 향상될 수 있지만,
# 과적합(overfitting)이 발생할 위험도 있습니다.
for epoch in range(300):

    # outputs = model(X_train)
    # 이 부분은 '순전파(Forward Propagation)' 과정입니다.
    # 훈련 데이터인 X_train을 모델(model)에 입력하여 예측값(outputs)을 계산합니다.
    # 데이터가 모델의 계층들을 순서대로 통과하며 최종 출력값을 생성합니다.
    outputs = model(X_train)

    # loss = crit(outputs, y_train.long())
    # 손실 함수(crit)를 사용하여 모델의 예측값(outputs)과 실제 정답(y_train) 사이의 오차를 계산합니다.
    # .long()은 정수 타입의 라벨을 사용하는 nn.CrossEntropyLoss()에 맞게 데이터 타입을 변환해주는 역할을 합니다.
    # 이 손실값(loss)이 작을수록 모델의 예측이 정확하다는 의미입니다.
    # 
    loss = crit(outputs, y_train.long())

    # opt.zero_grad()
    # '역전파(Backward Propagation)'를 시작하기 전에, 옵티마이저(opt)에 저장된
    # 모든 매개변수(가중치와 바이어스)의 기울기(gradient)를 0으로 초기화합니다.
    # 이는 이전 학습 단계에서 계산된 기울기가 현재 학습에 영향을 주지 않도록 하기 위함입니다.
    opt.zero_grad()

    # loss.backward()
    # 이 부분은 역전파의 핵심입니다.
    # 계산된 손실값(loss)을 바탕으로 모델의 각 매개변수에 대한 기울기(gradient)를 자동으로 계산합니다.
    # 이 기울기는 손실을 줄이는 방향으로 매개변수를 얼마나 변경해야 하는지를 알려줍니다.
    loss.backward()

    # opt.step()
    # '최적화(Optimization)' 단계입니다.
    # loss.backward()에서 계산된 기울기를 사용하여 옵티마이저(opt)가 모델의 매개변수를 업데이트합니다.
    # 예를 들어, Adam 옵티마이저는 이 기울기를 이용해 학습률(learning rate)에 따라 가중치와 바이어스를 수정합니다.
    # 이 과정을 통해 모델은 다음 번 순전파 때 더 나은 예측을 할 수 있게 됩니다.
    opt.step()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1773: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)

# %%
# 모델평가
with torch.no_grad():
  test_outputs = model(X_test)
  _, predicted = torch.max(test_outputs, 1)
  accuracy = (predicted==y_test).sum().item()/y_test.size(0)
  print(loss.item(), accuracy)
# Out:
# 0.6375702023506165 0.9777777777777777

# %%
# keras 함수형api 로 신경망 구성하기

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.layers import concatenate, Activation

input = Input(shape=(4,))
dense1 = Dense(50, activation='relu')(input)
dense2 = Dense(80, activation='relu')(input)
dense3 = Dense(30, activation='relu')(input)

# %%
x = concatenate([dense1, dense2, dense3])
output = Dense(3, activation='softmax')(x)
model = Model(inputs=input, outputs=output)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 4)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 50)        │        250 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 80)        │        400 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 30)        │        150 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(X_train, y_train, epochs=300, verbose=1)
history
# Out:
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.2820 - loss: 1.3916
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3521 - loss: 1.1462
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3535 - loss: 1.0604
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3603 - loss: 1.0199
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6556 - loss: 0.8997
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6802 - loss: 0.8556
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8269 - loss: 0.7889
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9081 - loss: 0.7572
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9084 - loss: 0.6981
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8446 - loss: 0.6889
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8065 - loss: 0.6375
# Epoch 12/300
# ...

# %%
loss, acc = model.evaluate(X_test, y_test)
loss,acc
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0736
# (0.06847632676362991, 1.0)

# %%
# 예측

# %%
import numpy as np
pred_proba = model.predict(X_test[:5])
pred_class = np.argmax(pred_proba, axis = 1)
pred_class
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# array([0, 1, 1, 0, 2])

# %%
from sklearn.metrics import classification_report
y_pred = pred_proba = model.predict(X_test).argmax(axis=1)
print(classification_report(y_test,y_pred))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        14
#          1.0       1.00      1.00      1.00        18
#          2.0       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
# 모델의 저장

# %%
model.save('iris_model.keras')

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/iris_model.keras')
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 4)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 50)        │        250 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 80)        │        400 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 30)        │        150 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
import json

json_str = model.to_json()

json_dic = json.loads(json_str)
with open('iris_model.json', 'w') as f:
  json.dump(json_dic, f, indent=4)
